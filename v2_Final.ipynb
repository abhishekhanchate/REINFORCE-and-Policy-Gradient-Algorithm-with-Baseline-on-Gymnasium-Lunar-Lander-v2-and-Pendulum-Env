# %%
# !pip install gymnasium[box2d]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[box2d]
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 10.5 MB/s eta 0:00:00
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Collecting pygame==2.1.3
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 32.0 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting swig==4.*
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.4 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Installing collected packages: swig, farama-notifications, box2d-py, pygame, jax-jumpy, gymnasium
#   Running setup.py install for box2d-py ... done
#   DEPRECATION: box2d-py was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. pip 23.1 will enforce this behaviour change. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 pygame-2.1.3 swig-4.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
ECEN 743: Reinforcement Learning
Policy Gradient Assignment
Code tested using
	1. gymnasium 0.27.1
	2. box2d-py  2.3.5
	3. pytorch   2.0.0
	4. Python    3.9.12
1 & 2 can be installed using pip install gymnasium[box2d]
General Instructions
1. This code consists of TODO blocks, read them carefully and complete each of the blocks
2. Type your code between the following lines
			###### TYPE YOUR CODE HERE ######
			#################################
3. The default hyperparameters should be able to solve LunarLander-v2 in the continuous setting
4. It is not necessary to modify the rest of the code for this assignment, feel free to do so if needed.
"""
import gymnasium as gym
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import math
from collections import deque

class value_network(nn.Module):
	'''
	Value Network: Designed to take in state as input and give value as output
	Used as a baseline in Policy Gradient (PG) algorithms
	'''
	def __init__(self,state_dim):
		'''
			state_dim (int): state dimenssion
		'''
		super(value_network, self).__init__()
		self.l1 = nn.Linear(state_dim, 64)
		self.l2 = nn.Linear(64, 64)
		self.l3 = nn.Linear(64, 1)

	def forward(self,state):
		'''
		Input: State
		Output: Value of state
		'''
		v = F.tanh(self.l1(state))
		v = F.tanh(self.l2(v))
		return self.l3(v)


class policy_network(nn.Module):
	'''
	Policy Network: Designed for continous action space, where given a 
	state, the network outputs the mean and standard deviation of the action
	'''
	def __init__(self,state_dim,action_dim,log_std = 0.0):
		"""
			state_dim (int): state dimenssion
			action_dim (int): action dimenssion
			log_std (float): log of standard deviation (std)
		"""
		super(policy_network, self).__init__()
		self.state_dim = state_dim
		self.action_dim = action_dim
		self.l1 = nn.Linear(state_dim,64)
		self.l2 = nn.Linear(64,64)
		self.mean = nn.Linear(64,action_dim)
		self.log_std = nn.Parameter(torch.ones(1, action_dim) * log_std)

	
	def forward(self,state):
		'''
		Input: State
		Output: Mean, log_std and std of action
		'''
		a = F.tanh(self.l1(state))
		a = F.tanh(self.l2(a))
		a_mean = self.mean(a)
		a_log_std = self.log_std.expand_as(a_mean)
		a_std = torch.exp(a_log_std)		
		return a_mean, a_log_std, a_std

	def select_action(self, state):
		'''
		Input: State
		Output: Sample drawn from a normal disribution with mean and std
		'''
		a_mean, _, a_std = self.forward(state)
		action = torch.normal(a_mean, a_std)
		return action
	
	def get_log_prob(self, state, action):
		'''
		Input: State, Action
		Output: log probabilities
		'''
		mean, log_std, std = self.forward(state)
		var = std.pow(2)
		log_density = -(action - mean).pow(2) / (2 * var) - 0.5 * math.log(2 * math.pi) - log_std
		return log_density.sum(1, keepdim=True)

# %%
env.reset()
# Out:
# (array([-0.14080818, -0.9900369 ,  0.00278129], dtype=float32), {})

# %%
class PGAgent():
	'''
	An agent that performs different variants of the PG algorithm
	'''
	def __init__(self,
	 state_dim, 
	 action_dim,
	 discount=0.99,
	 lr=1e-3,
	 gpu_index=0,
	 seed=0,
	 env="LunarLander-v2"
	 ):
		"""
			state_size (int): dimension of each state
			action_size (int): dimension of each action
			discount (float): discount factor
			lr (float): learning rate
			gpu_index (int): GPU used for training
			seed (int): Seed of simulation
			env (str): Name of environment
		"""
		self.state_dim = state_dim
		self.action_dim = action_dim
		self.discount = discount
		self.lr = lr
		self.device = torch.device('cuda', index=gpu_index) if torch.cuda.is_available() else torch.device('cpu')
		self.env_name = env
		self.seed = seed
		self.policy = policy_network(state_dim,action_dim)
		self.value = value_network(state_dim)
		self.optimizer_policy = torch.optim.Adam(self.policy.parameters(), lr=self.lr)
		self.optimizer_value = torch.optim.Adam(self.value.parameters(), lr=self.lr)

	def sample_traj(self,batch_size=2000,evaluate = False):
		'''
		Input: 
			batch_size: minimum batch size needed for update
			evaluate: flag to be set during evaluation
		Output:
			states, actions, rewards,not_dones, episodic reward 	
		'''
		self.policy.to("cpu") #Move network to CPU for sampling
		env = gym.make(args.env)
		states = []
		actions = []
		rewards = []
		n_dones = []
		curr_reward_list = []
		while len(states) < batch_size:
			state, _ = env.reset(seed=self.seed)
			curr_reward = 0
			for t in range(1000):
				state_ten = torch.from_numpy(state).float().unsqueeze(0)
				with torch.no_grad():
					if evaluate:
						action = self.policy(state_ten)[0][0].numpy() # Take mean action during evaluation
					else:
						action = self.policy.select_action(state_ten)[0].numpy() # Sample from distribution during training
				action = action.astype(np.float64)
				n_state,reward,terminated,truncated,_ = env.step(action) # Execute action in the environment
				done = terminated or truncated
				states.append(state)
				actions.append(action)
				rewards.append(reward)
				n_done = 0 if done else 1
				n_dones.append(n_done)
				state = n_state
				curr_reward += reward
				if done:
					break
			curr_reward_list.append(curr_reward)
		if evaluate:
			return np.mean(curr_reward_list)
		return states,actions,rewards,n_dones, np.mean(curr_reward_list)
	



	def update(self,states,actions,rewards,n_dones,update_type='Baseline'):
		'''
		TODO: Complete this block to update the policy using different variants of PG
		Inputs:
			states: list of states
			actions: list of actions
			rewards: list of rewards
			n_dones: list of not dones
			update_type: type of PG algorithm
		Output: 
			None
		'''
		self.policy.to(self.device) #Move policy to GPU
		if update_type == "Baseline":
			self.value.to(self.device)	#Move value to GPU
		states_ten = torch.from_numpy(np.stack(states)).to(self.device)   #Convert to tensor and move to GPU
		action_ten = torch.from_numpy(np.stack(actions)).to(self.device)  #Convert to tensor and move to GPU
		rewards_ten = torch.from_numpy(np.stack(rewards)).to(self.device) #Convert to tensor and move to GPU
		n_dones_ten = torch.from_numpy(np.stack(n_dones)).to(self.device) #Convert to tensor and move to GPU

		if update_type == "Rt":
				'''
				TODO: Peform PG using the cumulative discounted reward of the entire trajectory
				1. Compute the discounted reward of each trajectory (rt)
				2. rt should be of the same length as rewards_ten (refer to the homework for an exact formulation)
				3. Compute log probabilities using states_ten and action_ten
				4. Compute policy loss and update the policy
				'''
				rt = torch.zeros(rewards_ten.shape[0],1).to(self.device)
				for t in reversed(range(rewards_ten.shape[0])):
					if t == rewards_ten.shape[0] - 1:
						rt[t] = rewards_ten[t]
					else:
						rt[t] = rewards_ten[t] + self.discount * rt[t+1] * n_dones_ten[t+1]
				#mean, std = self.forward(states)
				#dist = torch.distributions.Normal(mean, std)
				#log_probs = dist.log_prob(actions).sum(dim=1, keepdim=True)
				#action_probs = self.policy(states_ten)
				#log_probs = torch.log(action_probs.gather(1, action_ten.unsqueeze(1)).squeeze())
				
				log_probs = self.policy.get_log_prob(states_ten, action_ten)
				policy_loss = -torch.mean(log_probs * rt.detach())
				self.optimizer_policy.zero_grad()
				policy_loss.backward()
				self.optimizer_policy.step()

			###### TYPE YOUR CODE HERE ######
			# Do steps 1-4
			#################################
			
			#################################

		if update_type == 'Gt':
			'''
			TODO: Peform PG using reward_to_go
			1. Compute reward_to_go (gt) using rewards_ten and n_dones_ten
			2. gt should be of the same length as rewards_ten
			3. Compute log probabilities using states_ten and action_ten
			4. Compute policy loss and update the policy
			'''
			def compute_reward_to_go(rewards, discount):
				'''
				Computes reward-to-go for a given list of rewards and discount factor

				Inputs:
					rewards (list): list of rewards
					discount (float): discount factor

				Output:
					rtg (list): list of reward-to-go
				'''
				rtg = [rewards[-1]]
				for i in range(len(rewards) - 2, -1, -1):
					rtg.insert(0, rewards[i] + discount * rtg[0])
				return rtg
				
			gt = torch.zeros(rewards_ten.shape[0],1).to(self.device)

			###### TYPE YOUR CODE HERE ######

			num_t = 1
			cumulative = 0
			for t in reversed(range(rewards_ten.shape[0])):
				if n_dones[t]==0:
					num_t += 1
				cumulative = (self.discount*cumulative*(n_dones_ten[t]) + rewards_ten[t])
				gt[t] = cumulative

			gt = (gt - gt.mean()) / gt.std() #Helps with learning stablity
			log_probs = self.policy.get_log_prob(states_ten,action_ten)
			policy_loss = -torch.sum(torch.mul(log_probs,gt))/num_t
			self.optimizer_policy.zero_grad()
			policy_loss.backward()
			self.optimizer_policy.step()
   
			###### TYPE YOUR CODE HERE ######
			# Compute log probabilities and update the policy
			#################################

		if update_type == 'Baseline':
			'''
			TODO: Peform PG using reward_to_go and baseline
			1. Compute values of states, this will be used as the baseline 
			2. Compute reward_to_go (gt) using rewards_ten and n_dones_ten
			3. gt should be of the same length as rewards_ten
			4. Compute advantages 
			5. Update the value network to predict gt for each state (L2 norm)
			6. Compute log probabilities using states_ten and action_ten
			7. Compute policy loss (using advantages) and update the policy
			'''
			with torch.no_grad():
				values_adv = self.value(states_ten)
			gt = torch.zeros(rewards_ten.shape[0],1).to(self.device)

			###### TYPE YOUR CODE HERE ######
			# Compute reward_to_go (gt) and advantages
			num_t = 1
			cumulative = 0
			for t in reversed(range(rewards_ten.shape[0])):
				if n_dones[t]==0:
					num_t += 1
				cumulative = (self.discount*cumulative*(n_dones_ten[t]) + rewards_ten[t])
				gt[t] = cumulative

			advantages = gt - values_adv
			advantages = (advantages - advantages.mean()) / advantages.std()

			###### TYPE YOUR CODE HERE ######
			# Do steps 5-7
			value_loss = F.mse_loss(gt,self.value(states_ten))
			self.optimizer_value.zero_grad()
			value_loss.backward()
			self.optimizer_value.step()
			log_probs = self.policy.get_log_prob(states_ten,action_ten)
			policy_loss = -torch.sum(torch.mul(log_probs,advantages))/num_t
			self.optimizer_policy.zero_grad()
			policy_loss.backward()
			self.optimizer_policy.step()


if __name__ == "__main__":
	parser = argparse.ArgumentParser()
	parser.add_argument("--env", default="Pendulum-v1")	 # Pendulum-v1 # LunarLander-v2	 # Gymnasium environment name
	parser.add_argument("--seed", default=0, type=int)               # Sets Gym, PyTorch and Numpy seeds
	parser.add_argument("--n-iter", default=200, type=int)   # 200         # Maximum number of training iterations
	parser.add_argument("--discount", default=0.99)              # 0.99    # Discount factor
	parser.add_argument("--batch-size", default=5000, type=int)   # 5000   # 10000 # Training samples in each batch of training
	parser.add_argument("--lr", default=3e-3,type=float)         # 5e-3 # 5e-2  # 1e-2 #   # Learning rate
	parser.add_argument("--gpu-index", default=0,type=int)		 # GPU index
	parser.add_argument("--algo", default="Rt",type=str)  # Baseline      # PG algorithm type. Baseline/Gt/Rt
	args = parser.parse_args(args=[])   # I added args=[] #

	# Making the environment	
	#env = gym.make(args.env, continuous=True, render_mode = 'rgb_array') # 
	env = gym.make(args.env, render_mode = 'rgb_array')

	#from gym import wrappers
	#env = wrappers.RecordVideo(gym.make('LunarLanderContinuous-v2'), force=True)


	state_dim = env.observation_space.shape[0]
	action_dim = env.action_space.shape[0]

	#env = gym.make(args.env,render_mode="rgb_array_list")
	#env = gym.wrappers.RecordVideo(env=env, step_trigger = 10, video_folder='./video')
 
	# Setting seeds
	torch.manual_seed(args.seed)
	np.random.seed(args.seed)
	random.seed(args.seed)


	kwargs = {
		"state_dim":state_dim,
		"action_dim":action_dim,
		"discount":args.discount,
		"lr":args.lr,
		"gpu_index":args.gpu_index,
		"seed":args.seed,
		"env":args.env
	}	
	learner = PGAgent(**kwargs) # Creating the PG learning agent

	moving_window = deque(maxlen=10)
 
	smoothened_cumulative_reward_history = [] ##################################################### Abhi 
	smoothened_cumulative_reward_history_train = [] ##################################################### Abhi
	consistency_count = 0	 ##################################################### Abhi

	for e in range(args.n_iter):
		'''
		Steps of PG algorithm
			1. Sample environment to gather data using a policy
			2. Update the policy using the data
			3. Evaluate the updated policy
			4. Repeat 1-3
		'''

		states,actions,rewards,n_dones,train_reward = learner.sample_traj(batch_size=args.batch_size)
		learner.update(states,actions,rewards,n_dones,args.algo)
		eval_reward= learner.sample_traj(evaluate=True)
		moving_window.append(eval_reward)
		print('Training Iteration {} Training Reward: {:.2f} Evaluation Reward: {:.2f} \
		Average Evaluation Reward: {:.2f}'.format(e,train_reward,eval_reward,np.mean(moving_window)))
		
		smoothened_cumulative_reward_history_train.append(train_reward)
		smoothened_cumulative_reward_history.append(np.mean(moving_window))
		if np.mean(moving_window)>=200.:
			consistency_count += 1
			if consistency_count == 100:
				torch.save(learner.Q.state_dict(),'./model.ckpt')
				break
		else:
			consistency_count = 0
		
		"""
		TODO: Write code for
		1. Logging and plotting
		2. Rendering the trained agent 
		"""
		###### TYPE YOUR CODE HERE ######
		#################################
		import os
		import imageio
		import numpy as np
		from PIL import Image
		import PIL.ImageDraw as ImageDraw
		import matplotlib.pyplot as plt    


		def _label_with_episode_number(frame, episode_num):
			im = Image.fromarray(frame)

			drawer = ImageDraw.Draw(im)

			if np.mean(im) < 128:
				text_color = (255,255,255)
			else:
				text_color = (0,0,0)
			drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

			return im


		def save_random_agent_gif(env):
			img = []
			for episodic in range(1):
				state, x = env.reset()

				while True:
					state = torch.from_numpy(state).float().unsqueeze(0)
					action = learner.policy(state)[0].detach().squeeze(0).numpy()
					next_state, r, tr, te, i = env.step(action)

					#display.clear_output(wait = True)
					img.append(env.render())
					state = next_state
					if tr or te:
						break

			env.close()
			imageio.mimwrite(os.path.join('drive/MyDrive/Ph. D. Coursework/ECEN743_ReinforcementLearning/A5/videos/', 'Pendulum-v1_RT.gif'), img, fps=60)
	 
	#env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')
	save_random_agent_gif(env)
# Out:
# Training Iteration 0 Training Reward: -946.43 Evaluation Reward: -1292.20 		Average Evaluation Reward: -1292.20
# Training Iteration 1 Training Reward: -1202.88 Evaluation Reward: -1115.74 		Average Evaluation Reward: -1203.97
# Training Iteration 2 Training Reward: -1044.46 Evaluation Reward: -1013.92 		Average Evaluation Reward: -1140.62
# Training Iteration 3 Training Reward: -1028.23 Evaluation Reward: -979.62 		Average Evaluation Reward: -1100.37
# Training Iteration 4 Training Reward: -959.97 Evaluation Reward: -1067.42 		Average Evaluation Reward: -1093.78
# Training Iteration 5 Training Reward: -977.44 Evaluation Reward: -1119.09 		Average Evaluation Reward: -1098.00
# Training Iteration 6 Training Reward: -1092.74 Evaluation Reward: -1069.70 		Average Evaluation Reward: -1093.96
# Training Iteration 7 Training Reward: -1064.96 Evaluation Reward: -881.87 		Average Evaluation Reward: -1067.45
# Training Iteration 8 Training Reward: -924.54 Evaluation Reward: -1011.93 		Average Evaluation Reward: -1061.28
# Training Iteration 9 Training Reward: -941.00 Evaluation Reward: -1039.67 		Average Evaluation Reward: -1059.12
# Training Iteration 10 Training Reward: -978.62 Evaluation Reward: -1041.88 		Average Evaluation Reward: -1034.08
# Training Iteration 11 Training Reward: -988.66 Evaluation Reward: -1024.95 		Average Evaluation Reward: -1025.00
# Training Iteration 12 Training Reward: -950.13 Evaluation Reward: -881.21 		Average Evaluation Reward: -1011.73
# Training Iteration 13 Training Reward: -911.42 Evaluation Reward: -1063.86 		Average Evaluation Reward: -1020.16
# Training Iteration 14 Training Reward: -1016.11 Evaluation Reward: -1152.80 		Average Evaluation Reward: -1028.70
# Training Iteration 15 Training Reward: -1135.66 Evaluation Reward: -1159.56 		Average Evaluation Reward: -1032.74
# Training Iteration 16 Training Reward: -1068.57 Evaluation Reward: -1175.55 		Average Evaluation Reward: -1043.33
# Training Iteration 17 Training Reward: -1136.35 Evaluation Reward: -1172.21 		Average Evaluation Reward: -1072.36
# Training Iteration 18 Training Reward: -1153.96 Evaluation Reward: -1149.19 		Average Evaluation Reward: -1086.09
# Training Iteration 19 Training Reward: -1086.10 Evaluation Reward: -1073.85 		Average Evaluation Reward: -1089.51
# Training Iteration 20 Training Reward: -1035.78 Evaluation Reward: -1060.25 		Average Evaluation Reward: -1091.35
# Training Iteration 21 Training Reward: -992.83 Evaluation Reward: -873.10 		Average Evaluation Reward: -1076.16
# Training Iteration 22 Training Reward: -959.82 Evaluation Reward: -894.20 		Average Evaluation Reward: -1077.46
# Training Iteration 23 Training Reward: -941.50 Evaluation Reward: -1015.28 		Average Evaluation Reward: -1072.60
# Training Iteration 24 Training Reward: -937.92 Evaluation Reward: -1035.77 		Average Evaluation Reward: -1060.90
# Training Iteration 25 Training Reward: -972.49 Evaluation Reward: -1037.09 		Average Evaluation Reward: -1048.65
# Training Iteration 26 Training Reward: -976.48 Evaluation Reward: -1040.70 		Average Evaluation Reward: -1035.16
# Training Iteration 27 Training Reward: -960.10 Evaluation Reward: -1042.85 		Average Evaluation Reward: -1022.23
# Training Iteration 28 Training Reward: -978.76 Evaluation Reward: -1036.73 		Average Evaluation Reward: -1010.98
# Training Iteration 29 Training Reward: -972.06 Evaluation Reward: -1020.62 		Average Evaluation Reward: -1005.66
# Training Iteration 30 Training Reward: -933.10 Evaluation Reward: -886.98 		Average Evaluation Reward: -988.33
# Training Iteration 31 Training Reward: -924.04 Evaluation Reward: -877.81 		Average Evaluation Reward: -988.80
# Training Iteration 32 Training Reward: -916.12 Evaluation Reward: -877.61 		Average Evaluation Reward: -987.14
# Training Iteration 33 Training Reward: -898.43 Evaluation Reward: -883.49 		Average Evaluation Reward: -973.97
# Training Iteration 34 Training Reward: -937.13 Evaluation Reward: -970.20 		Average Evaluation Reward: -967.41
# Training Iteration 35 Training Reward: -932.09 Evaluation Reward: -1024.63 		Average Evaluation Reward: -966.16
# Training Iteration 36 Training Reward: -962.46 Evaluation Reward: -1046.50 		Average Evaluation Reward: -966.74
# Training Iteration 37 Training Reward: -1004.74 Evaluation Reward: -1099.38 		Average Evaluation Reward: -972.40
# Training Iteration 38 Training Reward: -1064.82 Evaluation Reward: -1098.77 		Average Evaluation Reward: -978.60
# Training Iteration 39 Training Reward: -1044.11 Evaluation Reward: -1043.69 		Average Evaluation Reward: -980.91
# Training Iteration 40 Training Reward: -986.94 Evaluation Reward: -1005.28 		Average Evaluation Reward: -992.74
# Training Iteration 41 Training Reward: -990.95 Evaluation Reward: -984.48 		Average Evaluation Reward: -1003.40
# Training Iteration 42 Training Reward: -921.16 Evaluation Reward: -879.59 		Average Evaluation Reward: -1003.60
# Training Iteration 43 Training Reward: -925.01 Evaluation Reward: -1069.95 		Average Evaluation Reward: -1022.25
# Training Iteration 44 Training Reward: -1073.85 Evaluation Reward: -1159.91 		Average Evaluation Reward: -1041.22
# Training Iteration 45 Training Reward: -1088.94 Evaluation Reward: -1180.48 		Average Evaluation Reward: -1056.80
# Training Iteration 46 Training Reward: -1115.14 Evaluation Reward: -1261.02 		Average Evaluation Reward: -1078.25
# Training Iteration 47 Training Reward: -1215.22 Evaluation Reward: -1313.34 		Average Evaluation Reward: -1099.65
# Training Iteration 48 Training Reward: -1244.89 Evaluation Reward: -1412.13 		Average Evaluation Reward: -1130.99
# Training Iteration 49 Training Reward: -1393.80 Evaluation Reward: -1448.32 		Average Evaluation Reward: -1171.45
# Training Iteration 50 Training Reward: -1441.12 Evaluation Reward: -1422.30 		Average Evaluation Reward: -1213.15
# Training Iteration 51 Training Reward: -1385.32 Evaluation Reward: -1396.36 		Average Evaluation Reward: -1254.34
# Training Iteration 52 Training Reward: -1356.83 Evaluation Reward: -1374.22 		Average Evaluation Reward: -1303.80
# Training Iteration 53 Training Reward: -1332.50 Evaluation Reward: -1363.24 		Average Evaluation Reward: -1333.13
# Training Iteration 54 Training Reward: -1322.62 Evaluation Reward: -1369.42 		Average Evaluation Reward: -1354.08
# Training Iteration 55 Training Reward: -1328.94 Evaluation Reward: -1370.20 		Average Evaluation Reward: -1373.06
# Training Iteration 56 Training Reward: -1338.58 Evaluation Reward: -1352.50 		Average Evaluation Reward: -1382.20
# Training Iteration 57 Training Reward: -1329.88 Evaluation Reward: -1318.11 		Average Evaluation Reward: -1382.68
# Training Iteration 58 Training Reward: -1281.63 Evaluation Reward: -1281.76 		Average Evaluation Reward: -1369.64
# Training Iteration 59 Training Reward: -1213.99 Evaluation Reward: -1271.24 		Average Evaluation Reward: -1351.93
# Training Iteration 60 Training Reward: -1220.11 Evaluation Reward: -1254.76 		Average Evaluation Reward: -1335.18
# Training Iteration 61 Training Reward: -1213.25 Evaluation Reward: -1230.64 		Average Evaluation Reward: -1318.61
# Training Iteration 62 Training Reward: -1193.08 Evaluation Reward: -1209.33 		Average Evaluation Reward: -1302.12
# Training Iteration 63 Training Reward: -1143.36 Evaluation Reward: -1219.62 		Average Evaluation Reward: -1287.76
# Training Iteration 64 Training Reward: -1198.08 Evaluation Reward: -1210.29 		Average Evaluation Reward: -1271.85
# Training Iteration 65 Training Reward: -1216.23 Evaluation Reward: -1159.93 		Average Evaluation Reward: -1250.82
# Training Iteration 66 Training Reward: -1075.56 Evaluation Reward: -1109.93 		Average Evaluation Reward: -1226.56
# Training Iteration 67 Training Reward: -1070.45 Evaluation Reward: -1060.08 		Average Evaluation Reward: -1200.76
# Training Iteration 68 Training Reward: -1026.15 Evaluation Reward: -868.77 		Average Evaluation Reward: -1159.46
# Training Iteration 69 Training Reward: -955.60 Evaluation Reward: -874.95 		Average Evaluation Reward: -1119.83
# Training Iteration 70 Training Reward: -971.99 Evaluation Reward: -988.82 		Average Evaluation Reward: -1093.24
# Training Iteration 71 Training Reward: -932.51 Evaluation Reward: -959.49 		Average Evaluation Reward: -1066.12
# Training Iteration 72 Training Reward: -973.46 Evaluation Reward: -973.71 		Average Evaluation Reward: -1042.56
# Training Iteration 73 Training Reward: -955.31 Evaluation Reward: -991.09 		Average Evaluation Reward: -1019.71
# Training Iteration 74 Training Reward: -951.81 Evaluation Reward: -956.36 		Average Evaluation Reward: -994.31
# Training Iteration 75 Training Reward: -928.41 Evaluation Reward: -955.08 		Average Evaluation Reward: -973.83
# Training Iteration 76 Training Reward: -924.16 Evaluation Reward: -877.70 		Average Evaluation Reward: -950.60
# Training Iteration 77 Training Reward: -959.75 Evaluation Reward: -980.01 		Average Evaluation Reward: -942.60
# Training Iteration 78 Training Reward: -999.06 Evaluation Reward: -1066.43 		Average Evaluation Reward: -962.36
# Training Iteration 79 Training Reward: -1035.26 Evaluation Reward: -1102.79 		Average Evaluation Reward: -985.15
# Training Iteration 80 Training Reward: -1088.68 Evaluation Reward: -1120.82 		Average Evaluation Reward: -998.35
# Training Iteration 81 Training Reward: -1090.33 Evaluation Reward: -1093.48 		Average Evaluation Reward: -1011.75
# Training Iteration 82 Training Reward: -1083.28 Evaluation Reward: -1065.57 		Average Evaluation Reward: -1020.93
# Training Iteration 83 Training Reward: -1057.73 Evaluation Reward: -862.95 		Average Evaluation Reward: -1008.12
# Training Iteration 84 Training Reward: -930.84 Evaluation Reward: -974.09 		Average Evaluation Reward: -1009.89
# Training Iteration 85 Training Reward: -955.57 Evaluation Reward: -892.56 		Average Evaluation Reward: -1003.64
# Training Iteration 86 Training Reward: -966.74 Evaluation Reward: -898.97 		Average Evaluation Reward: -1005.77
# Training Iteration 87 Training Reward: -983.62 Evaluation Reward: -902.23 		Average Evaluation Reward: -997.99
# Training Iteration 88 Training Reward: -983.02 Evaluation Reward: -828.29 		Average Evaluation Reward: -974.18
# Training Iteration 89 Training Reward: -922.78 Evaluation Reward: -911.41 		Average Evaluation Reward: -955.04
# Training Iteration 90 Training Reward: -938.44 Evaluation Reward: -856.41 		Average Evaluation Reward: -928.60
# Training Iteration 91 Training Reward: -928.20 Evaluation Reward: -812.83 		Average Evaluation Reward: -900.53
# Training Iteration 92 Training Reward: -903.74 Evaluation Reward: -843.90 		Average Evaluation Reward: -878.36
# Training Iteration 93 Training Reward: -915.45 Evaluation Reward: -882.27 		Average Evaluation Reward: -880.30
# Training Iteration 94 Training Reward: -962.91 Evaluation Reward: -971.67 		Average Evaluation Reward: -880.05
# Training Iteration 95 Training Reward: -985.93 Evaluation Reward: -1057.84 		Average Evaluation Reward: -896.58
# Training Iteration 96 Training Reward: -985.71 Evaluation Reward: -1073.00 		Average Evaluation Reward: -913.98
# Training Iteration 97 Training Reward: -998.59 Evaluation Reward: -1146.78 		Average Evaluation Reward: -938.44
# Training Iteration 98 Training Reward: -1048.37 Evaluation Reward: -1190.23 		Average Evaluation Reward: -974.63
# Training Iteration 99 Training Reward: -1181.72 Evaluation Reward: -1209.62 		Average Evaluation Reward: -1004.45
# Training Iteration 100 Training Reward: -1170.15 Evaluation Reward: -1219.62 		Average Evaluation Reward: -1040.78
# Training Iteration 101 Training Reward: -1215.41 Evaluation Reward: -1204.13 		Average Evaluation Reward: -1079.91
# Training Iteration 102 Training Reward: -1179.45 Evaluation Reward: -1188.55 		Average Evaluation Reward: -1114.37
# Training Iteration 103 Training Reward: -1120.41 Evaluation Reward: -1188.50 		Average Evaluation Reward: -1144.99
# Training Iteration 104 Training Reward: -1167.76 Evaluation Reward: -1179.60 		Average Evaluation Reward: -1165.79
# Training Iteration 105 Training Reward: -1141.15 Evaluation Reward: -1166.49 		Average Evaluation Reward: -1176.65
# Training Iteration 106 Training Reward: -1083.63 Evaluation Reward: -1169.77 		Average Evaluation Reward: -1186.33
# Training Iteration 107 Training Reward: -1102.95 Evaluation Reward: -1177.41 		Average Evaluation Reward: -1189.39
# Training Iteration 108 Training Reward: -1123.05 Evaluation Reward: -1183.03 		Average Evaluation Reward: -1188.67
# Training Iteration 109 Training Reward: -1135.89 Evaluation Reward: -1194.37 		Average Evaluation Reward: -1187.15
# Training Iteration 110 Training Reward: -1153.32 Evaluation Reward: -1195.38 		Average Evaluation Reward: -1184.72
# Training Iteration 111 Training Reward: -1174.43 Evaluation Reward: -1181.13 		Average Evaluation Reward: -1182.42
# Training Iteration 112 Training Reward: -1143.67 Evaluation Reward: -1167.13 		Average Evaluation Reward: -1180.28
# Training Iteration 113 Training Reward: -1130.75 Evaluation Reward: -1122.64 		Average Evaluation Reward: -1173.70
# Training Iteration 114 Training Reward: -1069.44 Evaluation Reward: -1069.28 		Average Evaluation Reward: -1162.66
# Training Iteration 115 Training Reward: -1036.10 Evaluation Reward: -970.52 		Average Evaluation Reward: -1143.07
# Training Iteration 116 Training Reward: -980.31 Evaluation Reward: -938.47 		Average Evaluation Reward: -1119.94
# Training Iteration 117 Training Reward: -941.03 Evaluation Reward: -1035.73 		Average Evaluation Reward: -1105.77
# Training Iteration 118 Training Reward: -975.13 Evaluation Reward: -1046.17 		Average Evaluation Reward: -1092.08
# Training Iteration 119 Training Reward: -998.39 Evaluation Reward: -1036.33 		Average Evaluation Reward: -1076.28
# Training Iteration 120 Training Reward: -984.97 Evaluation Reward: -923.28 		Average Evaluation Reward: -1049.07
# Training Iteration 121 Training Reward: -952.24 Evaluation Reward: -903.00 		Average Evaluation Reward: -1021.26
# Training Iteration 122 Training Reward: -956.37 Evaluation Reward: -929.59 		Average Evaluation Reward: -997.50
# Training Iteration 123 Training Reward: -949.14 Evaluation Reward: -988.92 		Average Evaluation Reward: -984.13
# Training Iteration 124 Training Reward: -1006.29 Evaluation Reward: -1062.73 		Average Evaluation Reward: -983.47
# Training Iteration 125 Training Reward: -1013.64 Evaluation Reward: -1067.20 		Average Evaluation Reward: -993.14
# Training Iteration 126 Training Reward: -1043.66 Evaluation Reward: -1058.23 		Average Evaluation Reward: -1005.12
# Training Iteration 127 Training Reward: -998.03 Evaluation Reward: -1060.43 		Average Evaluation Reward: -1007.59
# Training Iteration 128 Training Reward: -995.61 Evaluation Reward: -1069.53 		Average Evaluation Reward: -1009.92
# Training Iteration 129 Training Reward: -1031.70 Evaluation Reward: -1068.79 		Average Evaluation Reward: -1013.17
# Training Iteration 130 Training Reward: -1023.31 Evaluation Reward: -1065.49 		Average Evaluation Reward: -1027.39
# Training Iteration 131 Training Reward: -973.96 Evaluation Reward: -1061.56 		Average Evaluation Reward: -1043.25
# Training Iteration 132 Training Reward: -1011.12 Evaluation Reward: -1022.77 		Average Evaluation Reward: -1052.56
# Training Iteration 133 Training Reward: -953.06 Evaluation Reward: -979.27 		Average Evaluation Reward: -1051.60
# Training Iteration 134 Training Reward: -974.98 Evaluation Reward: -969.23 		Average Evaluation Reward: -1042.25
# Training Iteration 135 Training Reward: -943.26 Evaluation Reward: -944.83 		Average Evaluation Reward: -1030.01
# Training Iteration 136 Training Reward: -942.26 Evaluation Reward: -858.84 		Average Evaluation Reward: -1010.08
# Training Iteration 137 Training Reward: -952.78 Evaluation Reward: -895.29 		Average Evaluation Reward: -993.56
# Training Iteration 138 Training Reward: -968.50 Evaluation Reward: -969.34 		Average Evaluation Reward: -983.54
# Training Iteration 139 Training Reward: -954.21 Evaluation Reward: -986.96 		Average Evaluation Reward: -975.36
# Training Iteration 140 Training Reward: -958.55 Evaluation Reward: -1068.81 		Average Evaluation Reward: -975.69
# Training Iteration 141 Training Reward: -1011.79 Evaluation Reward: -1074.35 		Average Evaluation Reward: -976.97
# Training Iteration 142 Training Reward: -1028.95 Evaluation Reward: -1103.93 		Average Evaluation Reward: -985.09
# Training Iteration 143 Training Reward: -1083.98 Evaluation Reward: -1124.41 		Average Evaluation Reward: -999.60
# Training Iteration 144 Training Reward: -1113.90 Evaluation Reward: -1085.59 		Average Evaluation Reward: -1011.24
# Training Iteration 145 Training Reward: -1057.34 Evaluation Reward: -1069.29 		Average Evaluation Reward: -1023.68
# Training Iteration 146 Training Reward: -1021.61 Evaluation Reward: -977.32 		Average Evaluation Reward: -1035.53
# Training Iteration 147 Training Reward: -938.81 Evaluation Reward: -956.92 		Average Evaluation Reward: -1041.69
# Training Iteration 148 Training Reward: -966.63 Evaluation Reward: -866.58 		Average Evaluation Reward: -1031.42
# Training Iteration 149 Training Reward: -946.08 Evaluation Reward: -903.43 		Average Evaluation Reward: -1023.06
# Training Iteration 150 Training Reward: -892.33 Evaluation Reward: -877.74 		Average Evaluation Reward: -1003.96
# Training Iteration 151 Training Reward: -927.21 Evaluation Reward: -982.02 		Average Evaluation Reward: -994.72
# Training Iteration 152 Training Reward: -929.98 Evaluation Reward: -1016.34 		Average Evaluation Reward: -985.97
# Training Iteration 153 Training Reward: -948.55 Evaluation Reward: -1027.78 		Average Evaluation Reward: -976.30
# Training Iteration 154 Training Reward: -958.23 Evaluation Reward: -1024.49 		Average Evaluation Reward: -970.19
# Training Iteration 155 Training Reward: -959.35 Evaluation Reward: -950.06 		Average Evaluation Reward: -958.27
# Training Iteration 156 Training Reward: -941.44 Evaluation Reward: -878.13 		Average Evaluation Reward: -948.35
# Training Iteration 157 Training Reward: -948.36 Evaluation Reward: -887.62 		Average Evaluation Reward: -941.42
# Training Iteration 158 Training Reward: -926.42 Evaluation Reward: -860.54 		Average Evaluation Reward: -940.82
# Training Iteration 159 Training Reward: -942.43 Evaluation Reward: -971.06 		Average Evaluation Reward: -947.58
# Training Iteration 160 Training Reward: -960.99 Evaluation Reward: -1059.52 		Average Evaluation Reward: -965.76
# Training Iteration 161 Training Reward: -1016.70 Evaluation Reward: -1069.62 		Average Evaluation Reward: -974.52
# Training Iteration 162 Training Reward: -1033.46 Evaluation Reward: -1059.27 		Average Evaluation Reward: -978.81
# Training Iteration 163 Training Reward: -988.85 Evaluation Reward: -986.68 		Average Evaluation Reward: -974.70
# Training Iteration 164 Training Reward: -936.90 Evaluation Reward: -970.69 		Average Evaluation Reward: -969.32
# Training Iteration 165 Training Reward: -965.23 Evaluation Reward: -967.23 		Average Evaluation Reward: -971.04
# Training Iteration 166 Training Reward: -949.04 Evaluation Reward: -860.78 		Average Evaluation Reward: -969.30
# Training Iteration 167 Training Reward: -915.01 Evaluation Reward: -860.81 		Average Evaluation Reward: -966.62
# Training Iteration 168 Training Reward: -929.75 Evaluation Reward: -861.98 		Average Evaluation Reward: -966.76
# Training Iteration 169 Training Reward: -949.39 Evaluation Reward: -874.29 		Average Evaluation Reward: -957.09
# Training Iteration 170 Training Reward: -899.92 Evaluation Reward: -900.69 		Average Evaluation Reward: -941.21
# Training Iteration 171 Training Reward: -926.77 Evaluation Reward: -933.32 		Average Evaluation Reward: -927.58
# Training Iteration 172 Training Reward: -916.62 Evaluation Reward: -923.10 		Average Evaluation Reward: -913.96
# Training Iteration 173 Training Reward: -948.54 Evaluation Reward: -939.05 		Average Evaluation Reward: -909.20
# Training Iteration 174 Training Reward: -938.44 Evaluation Reward: -941.40 		Average Evaluation Reward: -906.27
# Training Iteration 175 Training Reward: -950.90 Evaluation Reward: -900.05 		Average Evaluation Reward: -899.55
# Training Iteration 176 Training Reward: -916.62 Evaluation Reward: -874.64 		Average Evaluation Reward: -900.93
# Training Iteration 177 Training Reward: -934.18 Evaluation Reward: -858.97 		Average Evaluation Reward: -900.75
# Training Iteration 178 Training Reward: -966.82 Evaluation Reward: -944.55 		Average Evaluation Reward: -909.01
# Training Iteration 179 Training Reward: -959.21 Evaluation Reward: -928.61 		Average Evaluation Reward: -914.44
# Training Iteration 180 Training Reward: -979.03 Evaluation Reward: -871.17 		Average Evaluation Reward: -911.49
# Training Iteration 181 Training Reward: -915.77 Evaluation Reward: -879.37 		Average Evaluation Reward: -906.09
# Training Iteration 182 Training Reward: -953.16 Evaluation Reward: -860.82 		Average Evaluation Reward: -899.86
# Training Iteration 183 Training Reward: -958.84 Evaluation Reward: -834.39 		Average Evaluation Reward: -889.40
# Training Iteration 184 Training Reward: -917.08 Evaluation Reward: -840.67 		Average Evaluation Reward: -879.32
# Training Iteration 185 Training Reward: -943.50 Evaluation Reward: -856.13 		Average Evaluation Reward: -874.93
# Training Iteration 186 Training Reward: -933.73 Evaluation Reward: -858.02 		Average Evaluation Reward: -873.27
# Training Iteration 187 Training Reward: -958.65 Evaluation Reward: -763.14 		Average Evaluation Reward: -863.69
# Training Iteration 188 Training Reward: -906.69 Evaluation Reward: -826.75 		Average Evaluation Reward: -851.91
# Training Iteration 189 Training Reward: -911.29 Evaluation Reward: -848.78 		Average Evaluation Reward: -843.92
# Training Iteration 190 Training Reward: -942.39 Evaluation Reward: -911.13 		Average Evaluation Reward: -847.92
# Training Iteration 191 Training Reward: -927.35 Evaluation Reward: -969.44 		Average Evaluation Reward: -856.93
# Training Iteration 192 Training Reward: -969.29 Evaluation Reward: -959.05 		Average Evaluation Reward: -866.75
# Training Iteration 193 Training Reward: -921.86 Evaluation Reward: -865.42 		Average Evaluation Reward: -869.85
# Training Iteration 194 Training Reward: -936.71 Evaluation Reward: -826.65 		Average Evaluation Reward: -868.45
# Training Iteration 195 Training Reward: -938.16 Evaluation Reward: -879.26 		Average Evaluation Reward: -870.76
# Training Iteration 196 Training Reward: -960.56 Evaluation Reward: -885.76 		Average Evaluation Reward: -873.54
# Training Iteration 197 Training Reward: -906.51 Evaluation Reward: -900.00 		Average Evaluation Reward: -887.23
# Training Iteration 198 Training Reward: -955.07 Evaluation Reward: -899.08 		Average Evaluation Reward: -894.46
# Training Iteration 199 Training Reward: -942.51 Evaluation Reward: -889.35 		Average Evaluation Reward: -898.52

# %%
#save_random_agent_gif(env)

# %%
def _label_with_episode_number(frame, episode_num):
	im = Image.fromarray(frame)

	drawer = ImageDraw.Draw(im)

	if np.mean(im) < 128:
		text_color = (255,255,255)
	else:
		text_color = (0,0,0)
	drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

	return im


def save_random_agent_gif(env):
	img = []
	for episodic in range(1):
		state, x = env.reset()

		while True:
			state = torch.from_numpy(state).float().unsqueeze(0)
			action = learner.policy(state)[0].detach().squeeze(0).numpy()
			next_state, r, tr, te, i = env.step(action)

			display.clear_output(wait = True)
			img.append(env.render())
			state = next_state
			if tr or te:
				break

	env.close()
	imageio.mimwrite(os.path.join('My Drive/Ph. D. Coursework/ECEN743_ReinforcementLearning/A5/videos/', 'lunar_lander_RT.gif'), img, fps=60)

# %%
# now that training has finished, we can plot cumulative reward vs episodes
import pickle
from matplotlib import pyplot as plt
#pickle.dump(eval_reward, open('cum_rwe','wb'))
plt.subplots_adjust(bottom=0.2)
plt.plot(smoothened_cumulative_reward_history_train)
plt.title('Training')
plt.xlabel('Number of Episodes')
plt.ylabel('Episodic Undiscounted-cumulative Reward')
#plt.ylim([-1000, 1000])
#plt.xlim([0, 500])
# Out:
# Text(0, 0.5, 'Episodic Undiscounted-cumulative Reward')

# %%
# now that training has finished, we can plot cumulative reward vs episodes
import pickle
from matplotlib import pyplot as plt
#pickle.dump(eval_reward, open('cum_rwe','wb'))
plt.subplots_adjust(bottom=0.2)
plt.plot(smoothened_cumulative_reward_history)
plt.title('Evaluation')
plt.xlabel('Number of Episodes')
plt.ylabel('Episodic Undiscounted-cumulative Reward')
#plt.ylim([-1000, 1000])
#plt.xlim([0, 500])
# Out:
# Text(0, 0.5, 'Episodic Undiscounted-cumulative Reward')

# %%
import os
import imageio
import numpy as np
from PIL import Image
import PIL.ImageDraw as ImageDraw
import matplotlib.pyplot as plt    


def _label_with_episode_number(frame, episode_num):
    im = Image.fromarray(frame)

    drawer = ImageDraw.Draw(im)

    if np.mean(im) < 128:
        text_color = (255,255,255)
    else:
        text_color = (0,0,0)
    drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

    return im


def save_random_agent_gif(env):
    img = []
    for episodic in range(1):
        state, x = env.reset()

        while True:
            state = torch.from_numpy(state).float().unsqueeze(0)
            action = learner.policy(state)[0].detach().squeeze(0).numpy()
            next_state, r, tr, te, i = env.step(action)

            display.clear_output(wait = True)
            img.append(env.render())
            state = next_state
            if tr or te:
                break


    env.close()

    imageio.mimwrite(os.path.join('./video/', 'random_agent.gif'), img, fps=60)

# %%
env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')
save_random_agent_gif(env)

# %%
! pip install pyvirtualdisplay
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
from IPython import display
from pyvirtualdisplay import Display
from matplotlib import animation
seed = 12345

torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

d = Display()
d.start()

env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')

img = []
for episodic in range(1):
    state, x = env.reset()

    while True:
        state = torch.from_numpy(state).float().unsqueeze(0)
        action = learner.policy(state)[0].detach().squeeze(0).numpy()
        next_state, r, tr, te, i = env.step(action)

        display.clear_output(wait = True)
        img.append(env.render())
        state = next_state
        if tr or te:
            break

dpi = 72
interval = 50 #ms

plt.figure(figsize = (img[0].shape[1]/dpi, img[0].shape[0]/dpi), dpi = dpi)
patch = plt.imshow(img[0])
plt.axis = ("off")
animate = lambda i: patch.set_data(img[i])
ani = animation.FuncAnimation(plt.gcf(), animate, frames = len(img), interval = interval)
display.display(display.HTML(ani.to_jshtml()))

writervideo = animation.FFMpegWriter(fps = 30)
ani.save('baselineLunar.mp4', writer = writervideo)
plt.close()

# %%
# 10 min 1 second for Rt
# 10 min 24 seconds for Gt
# 10 min 19 seconds for Baseline
