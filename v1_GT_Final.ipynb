# %%
# !pip install gymnasium[box2d]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gymnasium[box2d]
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 10.5 MB/s eta 0:00:00
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (1.22.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (4.5.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]) (2.2.1)
# Collecting pygame==2.1.3
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 32.0 MB/s eta 0:00:00
# Collecting box2d-py==2.3.5
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 19.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting swig==4.*
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.4 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for box2d-py (setup.py) ... error
#   ERROR: Failed building wheel for box2d-py
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
# Installing collected packages: swig, farama-notifications, box2d-py, pygame, jax-jumpy, gymnasium
#   Running setup.py install for box2d-py ... done
#   DEPRECATION: box2d-py was installed using the legacy 'setup.py install' method, because a wheel could not be built for it. pip 23.1 will enforce this behaviour change. A possible replacement is to fix the wheel build issue reported above. Discussion can be found at https://github.com/pypa/pip/issues/8368
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.3.0
#     Uninstalling pygame-2.3.0:
#       Successfully uninstalled pygame-2.3.0
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 pygame-2.1.3 swig-4.1.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
"""
ECEN 743: Reinforcement Learning
Policy Gradient Assignment
Code tested using
	1. gymnasium 0.27.1
	2. box2d-py  2.3.5
	3. pytorch   2.0.0
	4. Python    3.9.12
1 & 2 can be installed using pip install gymnasium[box2d]
General Instructions
1. This code consists of TODO blocks, read them carefully and complete each of the blocks
2. Type your code between the following lines
			###### TYPE YOUR CODE HERE ######
			#################################
3. The default hyperparameters should be able to solve LunarLander-v2 in the continuous setting
4. It is not necessary to modify the rest of the code for this assignment, feel free to do so if needed.
"""
import gymnasium as gym
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import math
from collections import deque

class value_network(nn.Module):
	'''
	Value Network: Designed to take in state as input and give value as output
	Used as a baseline in Policy Gradient (PG) algorithms
	'''
	def __init__(self,state_dim):
		'''
			state_dim (int): state dimenssion
		'''
		super(value_network, self).__init__()
		self.l1 = nn.Linear(state_dim, 64)
		self.l2 = nn.Linear(64, 64)
		self.l3 = nn.Linear(64, 1)

	def forward(self,state):
		'''
		Input: State
		Output: Value of state
		'''
		v = F.tanh(self.l1(state))
		v = F.tanh(self.l2(v))
		return self.l3(v)


class policy_network(nn.Module):
	'''
	Policy Network: Designed for continous action space, where given a 
	state, the network outputs the mean and standard deviation of the action
	'''
	def __init__(self,state_dim,action_dim,log_std = 0.0):
		"""
			state_dim (int): state dimenssion
			action_dim (int): action dimenssion
			log_std (float): log of standard deviation (std)
		"""
		super(policy_network, self).__init__()
		self.state_dim = state_dim
		self.action_dim = action_dim
		self.l1 = nn.Linear(state_dim,64)
		self.l2 = nn.Linear(64,64)
		self.mean = nn.Linear(64,action_dim)
		self.log_std = nn.Parameter(torch.ones(1, action_dim) * log_std)

	
	def forward(self,state):
		'''
		Input: State
		Output: Mean, log_std and std of action
		'''
		a = F.tanh(self.l1(state))
		a = F.tanh(self.l2(a))
		a_mean = self.mean(a)
		a_log_std = self.log_std.expand_as(a_mean)
		a_std = torch.exp(a_log_std)		
		return a_mean, a_log_std, a_std

	def select_action(self, state):
		'''
		Input: State
		Output: Sample drawn from a normal disribution with mean and std
		'''
		a_mean, _, a_std = self.forward(state)
		action = torch.normal(a_mean, a_std)
		return action
	
	def get_log_prob(self, state, action):
		'''
		Input: State, Action
		Output: log probabilities
		'''
		mean, log_std, std = self.forward(state)
		var = std.pow(2)
		log_density = -(action - mean).pow(2) / (2 * var) - 0.5 * math.log(2 * math.pi) - log_std
		return log_density.sum(1, keepdim=True)

# %%
env.reset()
# Out:
# (array([ 0.00796156,  1.422306  ,  0.8063987 ,  0.5060121 , -0.00921862,
#         -0.18266156,  0.        ,  0.        ], dtype=float32),
#  {})

# %%
class PGAgent():
	'''
	An agent that performs different variants of the PG algorithm
	'''
	def __init__(self,
	 state_dim, 
	 action_dim,
	 discount=0.99,
	 lr=1e-3,
	 gpu_index=0,
	 seed=0,
	 env="LunarLander-v2"
	 ):
		"""
			state_size (int): dimension of each state
			action_size (int): dimension of each action
			discount (float): discount factor
			lr (float): learning rate
			gpu_index (int): GPU used for training
			seed (int): Seed of simulation
			env (str): Name of environment
		"""
		self.state_dim = state_dim
		self.action_dim = action_dim
		self.discount = discount
		self.lr = lr
		self.device = torch.device('cuda', index=gpu_index) if torch.cuda.is_available() else torch.device('cpu')
		self.env_name = env
		self.seed = seed
		self.policy = policy_network(state_dim,action_dim)
		self.value = value_network(state_dim)
		self.optimizer_policy = torch.optim.Adam(self.policy.parameters(), lr=self.lr)
		self.optimizer_value = torch.optim.Adam(self.value.parameters(), lr=self.lr)

	def sample_traj(self,batch_size=2000,evaluate = False):
		'''
		Input: 
			batch_size: minimum batch size needed for update
			evaluate: flag to be set during evaluation
		Output:
			states, actions, rewards,not_dones, episodic reward 	
		'''
		self.policy.to("cpu") #Move network to CPU for sampling
		env = gym.make(args.env,continuous=True)
		states = []
		actions = []
		rewards = []
		n_dones = []
		curr_reward_list = []
		while len(states) < batch_size:
			state, _ = env.reset(seed=self.seed)
			curr_reward = 0
			for t in range(1000):
				state_ten = torch.from_numpy(state).float().unsqueeze(0)
				with torch.no_grad():
					if evaluate:
						action = self.policy(state_ten)[0][0].numpy() # Take mean action during evaluation
					else:
						action = self.policy.select_action(state_ten)[0].numpy() # Sample from distribution during training
				action = action.astype(np.float64)
				n_state,reward,terminated,truncated,_ = env.step(action) # Execute action in the environment
				done = terminated or truncated
				states.append(state)
				actions.append(action)
				rewards.append(reward)
				n_done = 0 if done else 1
				n_dones.append(n_done)
				state = n_state
				curr_reward += reward
				if done:
					break
			curr_reward_list.append(curr_reward)
		if evaluate:
			return np.mean(curr_reward_list)
		return states,actions,rewards,n_dones, np.mean(curr_reward_list)
	



	def update(self,states,actions,rewards,n_dones,update_type='Baseline'):
		'''
		TODO: Complete this block to update the policy using different variants of PG
		Inputs:
			states: list of states
			actions: list of actions
			rewards: list of rewards
			n_dones: list of not dones
			update_type: type of PG algorithm
		Output: 
			None
		'''
		self.policy.to(self.device) #Move policy to GPU
		if update_type == "Baseline":
			self.value.to(self.device)	#Move value to GPU
		states_ten = torch.from_numpy(np.stack(states)).to(self.device)   #Convert to tensor and move to GPU
		action_ten = torch.from_numpy(np.stack(actions)).to(self.device)  #Convert to tensor and move to GPU
		rewards_ten = torch.from_numpy(np.stack(rewards)).to(self.device) #Convert to tensor and move to GPU
		n_dones_ten = torch.from_numpy(np.stack(n_dones)).to(self.device) #Convert to tensor and move to GPU

		if update_type == "Rt":
				'''
				TODO: Peform PG using the cumulative discounted reward of the entire trajectory
				1. Compute the discounted reward of each trajectory (rt)
				2. rt should be of the same length as rewards_ten (refer to the homework for an exact formulation)
				3. Compute log probabilities using states_ten and action_ten
				4. Compute policy loss and update the policy
				'''
				rt = torch.zeros(rewards_ten.shape[0],1).to(self.device)
				for t in reversed(range(rewards_ten.shape[0])):
					if t == rewards_ten.shape[0] - 1:
						rt[t] = rewards_ten[t]
					else:
						rt[t] = rewards_ten[t] + self.discount * rt[t+1] * n_dones_ten[t+1]
				#mean, std = self.forward(states)
				#dist = torch.distributions.Normal(mean, std)
				#log_probs = dist.log_prob(actions).sum(dim=1, keepdim=True)
				#action_probs = self.policy(states_ten)
				#log_probs = torch.log(action_probs.gather(1, action_ten.unsqueeze(1)).squeeze())
				
				log_probs = self.policy.get_log_prob(states_ten, action_ten)
				policy_loss = -torch.mean(log_probs * rt.detach())
				self.optimizer_policy.zero_grad()
				policy_loss.backward()
				self.optimizer_policy.step()

			###### TYPE YOUR CODE HERE ######
			# Do steps 1-4
			#################################
			
			#################################

		if update_type == 'Gt':
			'''
			TODO: Peform PG using reward_to_go
			1. Compute reward_to_go (gt) using rewards_ten and n_dones_ten
			2. gt should be of the same length as rewards_ten
			3. Compute log probabilities using states_ten and action_ten
			4. Compute policy loss and update the policy
			'''
			def compute_reward_to_go(rewards, discount):
				'''
				Computes reward-to-go for a given list of rewards and discount factor

				Inputs:
					rewards (list): list of rewards
					discount (float): discount factor

				Output:
					rtg (list): list of reward-to-go
				'''
				rtg = [rewards[-1]]
				for i in range(len(rewards) - 2, -1, -1):
					rtg.insert(0, rewards[i] + discount * rtg[0])
				return rtg
				
			gt = torch.zeros(rewards_ten.shape[0],1).to(self.device)

			###### TYPE YOUR CODE HERE ######

			num_t = 1
			cumulative = 0
			for t in reversed(range(rewards_ten.shape[0])):
				if n_dones[t]==0:
					num_t += 1
				cumulative = (self.discount*cumulative*(n_dones_ten[t]) + rewards_ten[t])
				gt[t] = cumulative

			gt = (gt - gt.mean()) / gt.std() #Helps with learning stablity
			log_probs = self.policy.get_log_prob(states_ten,action_ten)
			policy_loss = -torch.sum(torch.mul(log_probs,gt))/num_t
			self.optimizer_policy.zero_grad()
			policy_loss.backward()
			self.optimizer_policy.step()
   
			###### TYPE YOUR CODE HERE ######
			# Compute log probabilities and update the policy
			#################################

		if update_type == 'Baseline':
			'''
			TODO: Peform PG using reward_to_go and baseline
			1. Compute values of states, this will be used as the baseline 
			2. Compute reward_to_go (gt) using rewards_ten and n_dones_ten
			3. gt should be of the same length as rewards_ten
			4. Compute advantages 
			5. Update the value network to predict gt for each state (L2 norm)
			6. Compute log probabilities using states_ten and action_ten
			7. Compute policy loss (using advantages) and update the policy
			'''
			with torch.no_grad():
				values_adv = self.value(states_ten)
			gt = torch.zeros(rewards_ten.shape[0],1).to(self.device)

			###### TYPE YOUR CODE HERE ######
			# Compute reward_to_go (gt) and advantages	
			gt_temp = 0
			for i in reversed(range(len(rewards_ten))):
				gt_temp = rewards_ten[i] + self.discount*gt_temp*(1-n_dones_ten[i])
				gt[i] = gt_temp
			#################################
			advantages = gt - values_adv
			advantages = (advantages - advantages.mean()) / advantages.std()

			###### TYPE YOUR CODE HERE ######
			#self.optimizer_value.zero_grad()
			#value_loss = (advantages**2).mean()
			#value_loss.backward()
			#self.optimizer_value.step()
   
			# Do steps 5-7
			log_probs = self.policy.get_log_prob(states_ten, action_ten)
			policy_loss = (-log_probs * advantages).mean()
			self.optimizer_policy.zero_grad()
			policy_loss.backward()
			self.optimizer_policy.step()
			#################################



if __name__ == "__main__":
	parser = argparse.ArgumentParser()
	parser.add_argument("--env", default="LunarLander-v2")		 # Gymnasium environment name
	parser.add_argument("--seed", default=0, type=int)               # Sets Gym, PyTorch and Numpy seeds
	parser.add_argument("--n-iter", default=200, type=int)   # 200         # Maximum number of training iterations
	parser.add_argument("--discount", default=0.99)              # 0.99    # Discount factor
	parser.add_argument("--batch-size", default=5000, type=int)   # 5000    # Training samples in each batch of training
	parser.add_argument("--lr", default=0.001,type=float)         # 5e-3     # Learning rate
	parser.add_argument("--gpu-index", default=0,type=int)		 # GPU index
	parser.add_argument("--algo", default="Gt",type=str)  # Baseline      # PG algorithm type. Baseline/Gt/Rt
	args = parser.parse_args(args=[])   # I added args=[] #

	# Making the environment	
	env = gym.make(args.env, continuous=True, render_mode = 'rgb_array') # 


	#from gym import wrappers
	#env = wrappers.RecordVideo(gym.make('LunarLanderContinuous-v2'), force=True)


	state_dim = env.observation_space.shape[0]
	action_dim = env.action_space.shape[0]

	#env = gym.make(args.env,render_mode="rgb_array_list")
	#env = gym.wrappers.RecordVideo(env=env, step_trigger = 10, video_folder='./video')
 
	# Setting seeds
	torch.manual_seed(args.seed)
	np.random.seed(args.seed)
	random.seed(args.seed)


	kwargs = {
		"state_dim":state_dim,
		"action_dim":action_dim,
		"discount":args.discount,
		"lr":args.lr,
		"gpu_index":args.gpu_index,
		"seed":args.seed,
		"env":args.env
	}	
	learner = PGAgent(**kwargs) # Creating the PG learning agent

	moving_window = deque(maxlen=10)
 
	smoothened_cumulative_reward_history = [] ##################################################### Abhi 
	smoothened_cumulative_reward_history_train = [] ##################################################### Abhi
	consistency_count = 0	 ##################################################### Abhi

	for e in range(args.n_iter):
		'''
		Steps of PG algorithm
			1. Sample environment to gather data using a policy
			2. Update the policy using the data
			3. Evaluate the updated policy
			4. Repeat 1-3
		'''

		states,actions,rewards,n_dones,train_reward = learner.sample_traj(batch_size=args.batch_size)
		learner.update(states,actions,rewards,n_dones,args.algo)
		eval_reward= learner.sample_traj(evaluate=True)
		moving_window.append(eval_reward)
		print('Training Iteration {} Training Reward: {:.2f} Evaluation Reward: {:.2f} \
		Average Evaluation Reward: {:.2f}'.format(e,train_reward,eval_reward,np.mean(moving_window)))
		
		smoothened_cumulative_reward_history_train.append(train_reward)
		smoothened_cumulative_reward_history.append(np.mean(moving_window))
		if np.mean(moving_window)>=200.:
			consistency_count += 1
			if consistency_count == 100:
				torch.save(learner.Q.state_dict(),'./model.ckpt')
				break
		else:
			consistency_count = 0
		
		"""
		TODO: Write code for
		1. Logging and plotting
		2. Rendering the trained agent 
		"""
		###### TYPE YOUR CODE HERE ######
		#################################
		import os
		import imageio
		import numpy as np
		from PIL import Image
		import PIL.ImageDraw as ImageDraw
		import matplotlib.pyplot as plt    


		def _label_with_episode_number(frame, episode_num):
			im = Image.fromarray(frame)

			drawer = ImageDraw.Draw(im)

			if np.mean(im) < 128:
				text_color = (255,255,255)
			else:
				text_color = (0,0,0)
			drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

			return im


		def save_random_agent_gif(env):
			img = []
			for episodic in range(1):
				state, x = env.reset()

				while True:
					state = torch.from_numpy(state).float().unsqueeze(0)
					action = learner.policy(state)[0].detach().squeeze(0).numpy()
					next_state, r, tr, te, i = env.step(action)

					#display.clear_output(wait = True)
					img.append(env.render())
					state = next_state
					if tr or te:
						break

			env.close()
			imageio.mimwrite(os.path.join('drive/MyDrive/Ph. D. Coursework/ECEN743_ReinforcementLearning/A5/videos/', 'lunar_lander_GT.gif'), img, fps=60)
	 
	#env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')
	save_random_agent_gif(env)
# Out:
# Training Iteration 0 Training Reward: -80.02 Evaluation Reward: -119.06 		Average Evaluation Reward: -119.06
# Training Iteration 1 Training Reward: -96.47 Evaluation Reward: -119.06 		Average Evaluation Reward: -119.06
# Training Iteration 2 Training Reward: -85.33 Evaluation Reward: -116.31 		Average Evaluation Reward: -118.14
# Training Iteration 3 Training Reward: -82.99 Evaluation Reward: -60.29 		Average Evaluation Reward: -103.68
# Training Iteration 4 Training Reward: -70.45 Evaluation Reward: -70.66 		Average Evaluation Reward: -97.08
# Training Iteration 5 Training Reward: -74.54 Evaluation Reward: -105.90 		Average Evaluation Reward: -98.55
# Training Iteration 6 Training Reward: -96.17 Evaluation Reward: -151.77 		Average Evaluation Reward: -106.15
# Training Iteration 7 Training Reward: -78.02 Evaluation Reward: -137.79 		Average Evaluation Reward: -110.10
# Training Iteration 8 Training Reward: -109.57 Evaluation Reward: -158.29 		Average Evaluation Reward: -115.46
# Training Iteration 9 Training Reward: -71.49 Evaluation Reward: -142.08 		Average Evaluation Reward: -118.12
# Training Iteration 10 Training Reward: -95.05 Evaluation Reward: -216.48 		Average Evaluation Reward: -127.86
# Training Iteration 11 Training Reward: -60.63 Evaluation Reward: -178.32 		Average Evaluation Reward: -133.79
# Training Iteration 12 Training Reward: -70.45 Evaluation Reward: -231.62 		Average Evaluation Reward: -145.32
# Training Iteration 13 Training Reward: -80.26 Evaluation Reward: -215.37 		Average Evaluation Reward: -160.83
# Training Iteration 14 Training Reward: -65.57 Evaluation Reward: -215.77 		Average Evaluation Reward: -175.34
# Training Iteration 15 Training Reward: -74.52 Evaluation Reward: -216.38 		Average Evaluation Reward: -186.39
# Training Iteration 16 Training Reward: -62.52 Evaluation Reward: -217.42 		Average Evaluation Reward: -192.95
# Training Iteration 17 Training Reward: -65.52 Evaluation Reward: -218.65 		Average Evaluation Reward: -201.04
# Training Iteration 18 Training Reward: -60.05 Evaluation Reward: -216.49 		Average Evaluation Reward: -206.86
# Training Iteration 19 Training Reward: -61.43 Evaluation Reward: -217.54 		Average Evaluation Reward: -214.40
# Training Iteration 20 Training Reward: -54.59 Evaluation Reward: -219.13 		Average Evaluation Reward: -214.67
# Training Iteration 21 Training Reward: -56.44 Evaluation Reward: -220.76 		Average Evaluation Reward: -218.91
# Training Iteration 22 Training Reward: -44.96 Evaluation Reward: -220.01 		Average Evaluation Reward: -217.75
# Training Iteration 23 Training Reward: -44.00 Evaluation Reward: -223.29 		Average Evaluation Reward: -218.54
# Training Iteration 24 Training Reward: -49.03 Evaluation Reward: -227.73 		Average Evaluation Reward: -219.74
# Training Iteration 25 Training Reward: -45.08 Evaluation Reward: -229.37 		Average Evaluation Reward: -221.04
# Training Iteration 26 Training Reward: -73.32 Evaluation Reward: -236.04 		Average Evaluation Reward: -222.90
# Training Iteration 27 Training Reward: -62.96 Evaluation Reward: -240.03 		Average Evaluation Reward: -225.04
# Training Iteration 28 Training Reward: -95.86 Evaluation Reward: -240.60 		Average Evaluation Reward: -227.45
# Training Iteration 29 Training Reward: -144.06 Evaluation Reward: -234.62 		Average Evaluation Reward: -229.16
# Training Iteration 30 Training Reward: -107.64 Evaluation Reward: -224.82 		Average Evaluation Reward: -229.73
# Training Iteration 31 Training Reward: -129.90 Evaluation Reward: -212.58 		Average Evaluation Reward: -228.91
# Training Iteration 32 Training Reward: -150.36 Evaluation Reward: -189.23 		Average Evaluation Reward: -225.83
# Training Iteration 33 Training Reward: -66.07 Evaluation Reward: -174.02 		Average Evaluation Reward: -220.90
# Training Iteration 34 Training Reward: -33.24 Evaluation Reward: -163.56 		Average Evaluation Reward: -214.49
# Training Iteration 35 Training Reward: -26.77 Evaluation Reward: -155.46 		Average Evaluation Reward: -207.10
# Training Iteration 36 Training Reward: -27.05 Evaluation Reward: -140.64 		Average Evaluation Reward: -197.56
# Training Iteration 37 Training Reward: -21.66 Evaluation Reward: -137.82 		Average Evaluation Reward: -187.34
# Training Iteration 38 Training Reward: -6.51 Evaluation Reward: -132.91 		Average Evaluation Reward: -176.57
# Training Iteration 39 Training Reward: -2.68 Evaluation Reward: -234.76 		Average Evaluation Reward: -176.58
# Training Iteration 40 Training Reward: -17.05 Evaluation Reward: -178.24 		Average Evaluation Reward: -171.92
# Training Iteration 41 Training Reward: 8.00 Evaluation Reward: -109.88 		Average Evaluation Reward: -161.65
# Training Iteration 42 Training Reward: 3.69 Evaluation Reward: -105.43 		Average Evaluation Reward: -153.27
# Training Iteration 43 Training Reward: -4.77 Evaluation Reward: -99.22 		Average Evaluation Reward: -145.79
# Training Iteration 44 Training Reward: 12.78 Evaluation Reward: -64.80 		Average Evaluation Reward: -135.92
# Training Iteration 45 Training Reward: 12.74 Evaluation Reward: -95.69 		Average Evaluation Reward: -129.94
# Training Iteration 46 Training Reward: 22.35 Evaluation Reward: -148.60 		Average Evaluation Reward: -130.74
# Training Iteration 47 Training Reward: -2.79 Evaluation Reward: -154.25 		Average Evaluation Reward: -132.38
# Training Iteration 48 Training Reward: 27.40 Evaluation Reward: -152.75 		Average Evaluation Reward: -134.36
# Training Iteration 49 Training Reward: 34.91 Evaluation Reward: -158.82 		Average Evaluation Reward: -126.77
# Training Iteration 50 Training Reward: 28.87 Evaluation Reward: -180.61 		Average Evaluation Reward: -127.00
# Training Iteration 51 Training Reward: 11.62 Evaluation Reward: -194.03 		Average Evaluation Reward: -135.42
# Training Iteration 52 Training Reward: 0.40 Evaluation Reward: -201.20 		Average Evaluation Reward: -145.00
# Training Iteration 53 Training Reward: -4.17 Evaluation Reward: -223.46 		Average Evaluation Reward: -157.42
# Training Iteration 54 Training Reward: 18.23 Evaluation Reward: -218.56 		Average Evaluation Reward: -172.80
# Training Iteration 55 Training Reward: 3.69 Evaluation Reward: -204.70 		Average Evaluation Reward: -183.70
# Training Iteration 56 Training Reward: -19.11 Evaluation Reward: -197.97 		Average Evaluation Reward: -188.63
# Training Iteration 57 Training Reward: -20.84 Evaluation Reward: -190.94 		Average Evaluation Reward: -192.30
# Training Iteration 58 Training Reward: 22.91 Evaluation Reward: -178.34 		Average Evaluation Reward: -194.86
# Training Iteration 59 Training Reward: -20.52 Evaluation Reward: -160.97 		Average Evaluation Reward: -195.08
# Training Iteration 60 Training Reward: -4.61 Evaluation Reward: -132.13 		Average Evaluation Reward: -190.23
# Training Iteration 61 Training Reward: -22.67 Evaluation Reward: -100.95 		Average Evaluation Reward: -180.92
# Training Iteration 62 Training Reward: -32.01 Evaluation Reward: -120.19 		Average Evaluation Reward: -172.82
# Training Iteration 63 Training Reward: 10.80 Evaluation Reward: -76.20 		Average Evaluation Reward: -158.09
# Training Iteration 64 Training Reward: -1.44 Evaluation Reward: -117.87 		Average Evaluation Reward: -148.02
# Training Iteration 65 Training Reward: -7.59 Evaluation Reward: -99.19 		Average Evaluation Reward: -137.47
# Training Iteration 66 Training Reward: 4.06 Evaluation Reward: 139.25 		Average Evaluation Reward: -103.75
# Training Iteration 67 Training Reward: 53.00 Evaluation Reward: 221.23 		Average Evaluation Reward: -62.53
# Training Iteration 68 Training Reward: 17.24 Evaluation Reward: -173.95 		Average Evaluation Reward: -62.10
# Training Iteration 69 Training Reward: -9.44 Evaluation Reward: -56.62 		Average Evaluation Reward: -51.66
# Training Iteration 70 Training Reward: -2.65 Evaluation Reward: -100.99 		Average Evaluation Reward: -48.55
# Training Iteration 71 Training Reward: 23.57 Evaluation Reward: -147.77 		Average Evaluation Reward: -53.23
# Training Iteration 72 Training Reward: 47.27 Evaluation Reward: -152.95 		Average Evaluation Reward: -56.51
# Training Iteration 73 Training Reward: 15.61 Evaluation Reward: -146.78 		Average Evaluation Reward: -63.56
# Training Iteration 74 Training Reward: 56.53 Evaluation Reward: -140.89 		Average Evaluation Reward: -65.87
# Training Iteration 75 Training Reward: 50.80 Evaluation Reward: -138.91 		Average Evaluation Reward: -69.84
# Training Iteration 76 Training Reward: 49.37 Evaluation Reward: -116.48 		Average Evaluation Reward: -95.41
# Training Iteration 77 Training Reward: 64.19 Evaluation Reward: -119.84 		Average Evaluation Reward: -129.52
# Training Iteration 78 Training Reward: 61.09 Evaluation Reward: -86.94 		Average Evaluation Reward: -120.82
# Training Iteration 79 Training Reward: 54.60 Evaluation Reward: -115.45 		Average Evaluation Reward: -126.70
# Training Iteration 80 Training Reward: 94.31 Evaluation Reward: -114.68 		Average Evaluation Reward: -128.07
# Training Iteration 81 Training Reward: 48.59 Evaluation Reward: -122.88 		Average Evaluation Reward: -125.58
# Training Iteration 82 Training Reward: 53.44 Evaluation Reward: -127.41 		Average Evaluation Reward: -123.03
# Training Iteration 83 Training Reward: 53.65 Evaluation Reward: -122.99 		Average Evaluation Reward: -120.65
# Training Iteration 84 Training Reward: 47.08 Evaluation Reward: -110.25 		Average Evaluation Reward: -117.58
# Training Iteration 85 Training Reward: 41.15 Evaluation Reward: -127.32 		Average Evaluation Reward: -116.42
# Training Iteration 86 Training Reward: 39.12 Evaluation Reward: -124.86 		Average Evaluation Reward: -117.26
# Training Iteration 87 Training Reward: 27.10 Evaluation Reward: -120.78 		Average Evaluation Reward: -117.36
# Training Iteration 88 Training Reward: 54.74 Evaluation Reward: -124.83 		Average Evaluation Reward: -121.14
# Training Iteration 89 Training Reward: 27.26 Evaluation Reward: -127.47 		Average Evaluation Reward: -122.35
# Training Iteration 90 Training Reward: 50.15 Evaluation Reward: 169.88 		Average Evaluation Reward: -93.89
# Training Iteration 91 Training Reward: 56.21 Evaluation Reward: -86.96 		Average Evaluation Reward: -90.30
# Training Iteration 92 Training Reward: 69.49 Evaluation Reward: -56.08 		Average Evaluation Reward: -83.17
# Training Iteration 93 Training Reward: 71.36 Evaluation Reward: -34.77 		Average Evaluation Reward: -74.34
# Training Iteration 94 Training Reward: 79.22 Evaluation Reward: 193.24 		Average Evaluation Reward: -44.00
# Training Iteration 95 Training Reward: 104.88 Evaluation Reward: 180.46 		Average Evaluation Reward: -13.22
# Training Iteration 96 Training Reward: 77.10 Evaluation Reward: 175.05 		Average Evaluation Reward: 16.77
# Training Iteration 97 Training Reward: 108.29 Evaluation Reward: 181.47 		Average Evaluation Reward: 47.00
# Training Iteration 98 Training Reward: 117.73 Evaluation Reward: 174.42 		Average Evaluation Reward: 76.92
# Training Iteration 99 Training Reward: 77.24 Evaluation Reward: 186.98 		Average Evaluation Reward: 108.37
# Training Iteration 100 Training Reward: 57.07 Evaluation Reward: -58.33 		Average Evaluation Reward: 85.55
# Training Iteration 101 Training Reward: 78.99 Evaluation Reward: -43.74 		Average Evaluation Reward: 89.87
# Training Iteration 102 Training Reward: 69.70 Evaluation Reward: -91.99 		Average Evaluation Reward: 86.28
# Training Iteration 103 Training Reward: 105.56 Evaluation Reward: -117.91 		Average Evaluation Reward: 77.97
# Training Iteration 104 Training Reward: 108.77 Evaluation Reward: -122.62 		Average Evaluation Reward: 46.38
# Training Iteration 105 Training Reward: 86.59 Evaluation Reward: -127.97 		Average Evaluation Reward: 15.54
# Training Iteration 106 Training Reward: 106.70 Evaluation Reward: -132.07 		Average Evaluation Reward: -15.18
# Training Iteration 107 Training Reward: 100.81 Evaluation Reward: -138.42 		Average Evaluation Reward: -47.16
# Training Iteration 108 Training Reward: 90.20 Evaluation Reward: -153.62 		Average Evaluation Reward: -79.97
# Training Iteration 109 Training Reward: 93.43 Evaluation Reward: -167.24 		Average Evaluation Reward: -115.39
# Training Iteration 110 Training Reward: 74.89 Evaluation Reward: -182.16 		Average Evaluation Reward: -127.77
# Training Iteration 111 Training Reward: 89.93 Evaluation Reward: -183.28 		Average Evaluation Reward: -141.73
# Training Iteration 112 Training Reward: 86.80 Evaluation Reward: -189.13 		Average Evaluation Reward: -151.44
# Training Iteration 113 Training Reward: 64.83 Evaluation Reward: -185.07 		Average Evaluation Reward: -158.16
# Training Iteration 114 Training Reward: 83.65 Evaluation Reward: -185.20 		Average Evaluation Reward: -164.42
# Training Iteration 115 Training Reward: 113.40 Evaluation Reward: -168.84 		Average Evaluation Reward: -168.50
# Training Iteration 116 Training Reward: 109.70 Evaluation Reward: 108.44 		Average Evaluation Reward: -144.45
# Training Iteration 117 Training Reward: 96.99 Evaluation Reward: -93.81 		Average Evaluation Reward: -139.99
# Training Iteration 118 Training Reward: 124.32 Evaluation Reward: 130.77 		Average Evaluation Reward: -111.55
# Training Iteration 119 Training Reward: 109.86 Evaluation Reward: -41.74 		Average Evaluation Reward: -99.00
# Training Iteration 120 Training Reward: 110.20 Evaluation Reward: 7.06 		Average Evaluation Reward: -80.08
# Training Iteration 121 Training Reward: 140.52 Evaluation Reward: 18.86 		Average Evaluation Reward: -59.86
# Training Iteration 122 Training Reward: 106.33 Evaluation Reward: 206.94 		Average Evaluation Reward: -20.26
# Training Iteration 123 Training Reward: 136.16 Evaluation Reward: -21.29 		Average Evaluation Reward: -3.88
# Training Iteration 124 Training Reward: 129.81 Evaluation Reward: -1.88 		Average Evaluation Reward: 14.45
# Training Iteration 125 Training Reward: 140.63 Evaluation Reward: 205.19 		Average Evaluation Reward: 51.86
# Training Iteration 126 Training Reward: 148.39 Evaluation Reward: -1.49 		Average Evaluation Reward: 40.86
# Training Iteration 127 Training Reward: 150.42 Evaluation Reward: -6.67 		Average Evaluation Reward: 49.58
# Training Iteration 128 Training Reward: 151.36 Evaluation Reward: 1.02 		Average Evaluation Reward: 36.60
# Training Iteration 129 Training Reward: 121.80 Evaluation Reward: 16.33 		Average Evaluation Reward: 42.41
# Training Iteration 130 Training Reward: 110.19 Evaluation Reward: 6.82 		Average Evaluation Reward: 42.38
# Training Iteration 131 Training Reward: 144.54 Evaluation Reward: 263.74 		Average Evaluation Reward: 66.87
# Training Iteration 132 Training Reward: 105.21 Evaluation Reward: 266.16 		Average Evaluation Reward: 72.79
# Training Iteration 133 Training Reward: 110.76 Evaluation Reward: 265.92 		Average Evaluation Reward: 101.51
# Training Iteration 134 Training Reward: 118.94 Evaluation Reward: 253.05 		Average Evaluation Reward: 127.01
# Training Iteration 135 Training Reward: 144.96 Evaluation Reward: 256.31 		Average Evaluation Reward: 132.12
# Training Iteration 136 Training Reward: 148.25 Evaluation Reward: 234.98 		Average Evaluation Reward: 155.77
# Training Iteration 137 Training Reward: 124.45 Evaluation Reward: 234.87 		Average Evaluation Reward: 179.92
# Training Iteration 138 Training Reward: 114.65 Evaluation Reward: 251.24 		Average Evaluation Reward: 204.94
# Training Iteration 139 Training Reward: 144.89 Evaluation Reward: 228.07 		Average Evaluation Reward: 226.12
# Training Iteration 140 Training Reward: 89.24 Evaluation Reward: 234.77 		Average Evaluation Reward: 248.91
# Training Iteration 141 Training Reward: 126.46 Evaluation Reward: 242.88 		Average Evaluation Reward: 246.83
# Training Iteration 142 Training Reward: 139.18 Evaluation Reward: -67.44 		Average Evaluation Reward: 213.46
# Training Iteration 143 Training Reward: 148.61 Evaluation Reward: 133.17 		Average Evaluation Reward: 200.19
# Training Iteration 144 Training Reward: 112.55 Evaluation Reward: 133.76 		Average Evaluation Reward: 188.26
# Training Iteration 145 Training Reward: 123.19 Evaluation Reward: 135.49 		Average Evaluation Reward: 176.18
# Training Iteration 146 Training Reward: 126.89 Evaluation Reward: 135.40 		Average Evaluation Reward: 166.22
# Training Iteration 147 Training Reward: 111.94 Evaluation Reward: 171.13 		Average Evaluation Reward: 159.85
# Training Iteration 148 Training Reward: 145.80 Evaluation Reward: -31.96 		Average Evaluation Reward: 131.53
# Training Iteration 149 Training Reward: 152.02 Evaluation Reward: 22.95 		Average Evaluation Reward: 111.01
# Training Iteration 150 Training Reward: 151.46 Evaluation Reward: 221.09 		Average Evaluation Reward: 109.65
# Training Iteration 151 Training Reward: 154.80 Evaluation Reward: 226.12 		Average Evaluation Reward: 107.97
# Training Iteration 152 Training Reward: 148.23 Evaluation Reward: 255.11 		Average Evaluation Reward: 140.23
# Training Iteration 153 Training Reward: 134.55 Evaluation Reward: 27.04 		Average Evaluation Reward: 129.61
# Training Iteration 154 Training Reward: 132.64 Evaluation Reward: 16.61 		Average Evaluation Reward: 117.90
# Training Iteration 155 Training Reward: 146.52 Evaluation Reward: 22.12 		Average Evaluation Reward: 106.56
# Training Iteration 156 Training Reward: 127.25 Evaluation Reward: 22.76 		Average Evaluation Reward: 95.30
# Training Iteration 157 Training Reward: 138.06 Evaluation Reward: 24.94 		Average Evaluation Reward: 80.68
# Training Iteration 158 Training Reward: 119.95 Evaluation Reward: 219.63 		Average Evaluation Reward: 105.84
# Training Iteration 159 Training Reward: 141.73 Evaluation Reward: 281.30 		Average Evaluation Reward: 131.67
# Training Iteration 160 Training Reward: 159.61 Evaluation Reward: 268.68 		Average Evaluation Reward: 136.43
# Training Iteration 161 Training Reward: 135.23 Evaluation Reward: 269.73 		Average Evaluation Reward: 140.79
# Training Iteration 162 Training Reward: 117.85 Evaluation Reward: 283.93 		Average Evaluation Reward: 143.67
# Training Iteration 163 Training Reward: 123.41 Evaluation Reward: 284.73 		Average Evaluation Reward: 169.44
# Training Iteration 164 Training Reward: 173.51 Evaluation Reward: 290.81 		Average Evaluation Reward: 196.86
# Training Iteration 165 Training Reward: 152.14 Evaluation Reward: 288.24 		Average Evaluation Reward: 223.48
# Training Iteration 166 Training Reward: 144.40 Evaluation Reward: 67.72 		Average Evaluation Reward: 227.97
# Training Iteration 167 Training Reward: 138.91 Evaluation Reward: 291.43 		Average Evaluation Reward: 254.62
# Training Iteration 168 Training Reward: 134.03 Evaluation Reward: 289.55 		Average Evaluation Reward: 261.61
# Training Iteration 169 Training Reward: 124.18 Evaluation Reward: 287.77 		Average Evaluation Reward: 262.26
# Training Iteration 170 Training Reward: 156.07 Evaluation Reward: 281.01 		Average Evaluation Reward: 263.49
# Training Iteration 171 Training Reward: 123.13 Evaluation Reward: 283.45 		Average Evaluation Reward: 264.86
# Training Iteration 172 Training Reward: 152.21 Evaluation Reward: -6.37 		Average Evaluation Reward: 235.84
# Training Iteration 173 Training Reward: 169.25 Evaluation Reward: 12.17 		Average Evaluation Reward: 208.58
# Training Iteration 174 Training Reward: 166.69 Evaluation Reward: 257.96 		Average Evaluation Reward: 205.29
# Training Iteration 175 Training Reward: 161.61 Evaluation Reward: 16.32 		Average Evaluation Reward: 178.10
# Training Iteration 176 Training Reward: 163.65 Evaluation Reward: 258.31 		Average Evaluation Reward: 197.16
# Training Iteration 177 Training Reward: 162.53 Evaluation Reward: 259.95 		Average Evaluation Reward: 194.01
# Training Iteration 178 Training Reward: 145.34 Evaluation Reward: 259.19 		Average Evaluation Reward: 190.98
# Training Iteration 179 Training Reward: 163.76 Evaluation Reward: 269.03 		Average Evaluation Reward: 189.10
# Training Iteration 180 Training Reward: 159.96 Evaluation Reward: 269.41 		Average Evaluation Reward: 187.94
# Training Iteration 181 Training Reward: 144.62 Evaluation Reward: 267.46 		Average Evaluation Reward: 186.34
# Training Iteration 182 Training Reward: 132.04 Evaluation Reward: 269.88 		Average Evaluation Reward: 213.97
# Training Iteration 183 Training Reward: 171.20 Evaluation Reward: 272.78 		Average Evaluation Reward: 240.03
# Training Iteration 184 Training Reward: 168.45 Evaluation Reward: 277.66 		Average Evaluation Reward: 242.00
# Training Iteration 185 Training Reward: 165.85 Evaluation Reward: 273.10 		Average Evaluation Reward: 267.68
# Training Iteration 186 Training Reward: 167.93 Evaluation Reward: 278.19 		Average Evaluation Reward: 269.66
# Training Iteration 187 Training Reward: 104.61 Evaluation Reward: 278.29 		Average Evaluation Reward: 271.50
# Training Iteration 188 Training Reward: 169.05 Evaluation Reward: 274.94 		Average Evaluation Reward: 273.07
# Training Iteration 189 Training Reward: 124.32 Evaluation Reward: 278.97 		Average Evaluation Reward: 274.07
# Training Iteration 190 Training Reward: 136.46 Evaluation Reward: 273.40 		Average Evaluation Reward: 274.47
# Training Iteration 191 Training Reward: 150.99 Evaluation Reward: 267.95 		Average Evaluation Reward: 274.52
# Training Iteration 192 Training Reward: 144.32 Evaluation Reward: 277.21 		Average Evaluation Reward: 275.25
# Training Iteration 193 Training Reward: 170.92 Evaluation Reward: 281.34 		Average Evaluation Reward: 276.11
# Training Iteration 194 Training Reward: 172.49 Evaluation Reward: 282.85 		Average Evaluation Reward: 276.62
# Training Iteration 195 Training Reward: 177.65 Evaluation Reward: 286.04 		Average Evaluation Reward: 277.92
# Training Iteration 196 Training Reward: 174.45 Evaluation Reward: 285.25 		Average Evaluation Reward: 278.62
# Training Iteration 197 Training Reward: 173.26 Evaluation Reward: 280.03 		Average Evaluation Reward: 278.80
# Training Iteration 198 Training Reward: 155.81 Evaluation Reward: -1.90 		Average Evaluation Reward: 251.11
# Training Iteration 199 Training Reward: 174.52 Evaluation Reward: -19.74 		Average Evaluation Reward: 221.24

# %%
#save_random_agent_gif(env)

# %%
def _label_with_episode_number(frame, episode_num):
	im = Image.fromarray(frame)

	drawer = ImageDraw.Draw(im)

	if np.mean(im) < 128:
		text_color = (255,255,255)
	else:
		text_color = (0,0,0)
	drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

	return im


def save_random_agent_gif(env):
	img = []
	for episodic in range(1):
		state, x = env.reset()

		while True:
			state = torch.from_numpy(state).float().unsqueeze(0)
			action = learner.policy(state)[0].detach().squeeze(0).numpy()
			next_state, r, tr, te, i = env.step(action)

			display.clear_output(wait = True)
			img.append(env.render())
			state = next_state
			if tr or te:
				break

	env.close()
	imageio.mimwrite(os.path.join('My Drive/Ph. D. Coursework/ECEN743_ReinforcementLearning/A5/videos/', 'lunar_lander_RT.gif'), img, fps=60)

# %%
# now that training has finished, we can plot cumulative reward vs episodes
import pickle
from matplotlib import pyplot as plt
#pickle.dump(eval_reward, open('cum_rwe','wb'))
plt.subplots_adjust(bottom=0.2)
plt.plot(smoothened_cumulative_reward_history_train)
plt.title('Training')
plt.xlabel('Number of Episodes')
plt.ylabel('Episodic Undiscounted-cumulative Reward')
#plt.ylim([-1000, 1000])
#plt.xlim([0, 500])
# Out:
# Text(0, 0.5, 'Episodic Undiscounted-cumulative Reward')

# %%
# now that training has finished, we can plot cumulative reward vs episodes
import pickle
from matplotlib import pyplot as plt
#pickle.dump(eval_reward, open('cum_rwe','wb'))
plt.subplots_adjust(bottom=0.2)
plt.plot(smoothened_cumulative_reward_history)
plt.title('Evaluation')
plt.xlabel('Number of Episodes')
plt.ylabel('Episodic Undiscounted-cumulative Reward')
#plt.ylim([-1000, 1000])
#plt.xlim([0, 500])
# Out:
# Text(0, 0.5, 'Episodic Undiscounted-cumulative Reward')

# %%
import os
import imageio
import numpy as np
from PIL import Image
import PIL.ImageDraw as ImageDraw
import matplotlib.pyplot as plt    


def _label_with_episode_number(frame, episode_num):
    im = Image.fromarray(frame)

    drawer = ImageDraw.Draw(im)

    if np.mean(im) < 128:
        text_color = (255,255,255)
    else:
        text_color = (0,0,0)
    drawer.text((im.size[0]/20,im.size[1]/18), f'Episode: {episode_num+1}', fill=text_color)

    return im


def save_random_agent_gif(env):
    img = []
    for episodic in range(1):
        state, x = env.reset()

        while True:
            state = torch.from_numpy(state).float().unsqueeze(0)
            action = learner.policy(state)[0].detach().squeeze(0).numpy()
            next_state, r, tr, te, i = env.step(action)

            display.clear_output(wait = True)
            img.append(env.render())
            state = next_state
            if tr or te:
                break


    env.close()

    imageio.mimwrite(os.path.join('./video/', 'random_agent.gif'), img, fps=60)

# %%
env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')
save_random_agent_gif(env)

# %%
! pip install pyvirtualdisplay
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
from IPython import display
from pyvirtualdisplay import Display
from matplotlib import animation
seed = 12345

torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

d = Display()
d.start()

env = gym.make("LunarLander-v2", continuous = True, render_mode = 'rgb_array')

img = []
for episodic in range(1):
    state, x = env.reset()

    while True:
        state = torch.from_numpy(state).float().unsqueeze(0)
        action = learner.policy(state)[0].detach().squeeze(0).numpy()
        next_state, r, tr, te, i = env.step(action)

        display.clear_output(wait = True)
        img.append(env.render())
        state = next_state
        if tr or te:
            break

dpi = 72
interval = 50 #ms

plt.figure(figsize = (img[0].shape[1]/dpi, img[0].shape[0]/dpi), dpi = dpi)
patch = plt.imshow(img[0])
plt.axis = ("off")
animate = lambda i: patch.set_data(img[i])
ani = animation.FuncAnimation(plt.gcf(), animate, frames = len(img), interval = interval)
display.display(display.HTML(ani.to_jshtml()))

writervideo = animation.FFMpegWriter(fps = 30)
ani.save('baselineLunar.mp4', writer = writervideo)
plt.close()

# %%
# 10 min 1 second for Rt
# 10 min 24 seconds for Gt
# 10 min 19 seconds for Baseline
